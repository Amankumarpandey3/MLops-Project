# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
print(df.head())
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
data = df.to_dict(orient='records')

# %%
DB_NAME = "Proj1"

# %%
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://amankumarpandey1712004_db_user:kumar12345@cluster0.8wgvo60.mongodb.net/"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
import sys
print(sys.version)
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
# Out:
# 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://amankumarpandey1712004_db_user:kumar12345@cluster0.8wgvo60.mongodb.net/"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
rec = collection.insert_many(data)

# %%
df = pd.DataFrame(list(collection.find()))
if df.empty:
    print("The collection is empty. Please ensure data is inserted into the MongoDB collection.")
else:
    print(df.head(2))
# Out:
#                         _id  id Gender  Age  Driving_License  Region_Code  \
# 0  693082530ed1073c0ab9f839   1   Male   44                1         28.0
# 1  693082530ed1073c0ab9f83a   2   Male   76                1          3.0
#
#    Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                   0   > 2 Years            Yes         40454.0
# 1                   0    1-2 Year             No         33536.0
#
#    Policy_Sales_Channel  Vintage  Response
# 0                  26.0      217         1
# 1                  26.0      183         0
